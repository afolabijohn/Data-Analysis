# %% [markdown]
# # DATA ANALYSIS WITH PANDAS

# %%
import pandas as pd

# %%
#import the data set from the url link specified below

# %% [markdown]
# #   We going to Analysis the dataset with pandas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
#pd.DataFrame makes a dataframe which is a multi dimensional array

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#import the numpy libray

# %%
import numpy as np

# %%
#get the first 5 values of the data set

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#isna is to check for NA values then the sum() function is to sum it all together

# %%
df.isna().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#you can also check empty values with the any()method

# %%
df.isnull().any()
# Out:
# record_id                       False
# utility_id_ferc1                False
# report_year                     False
# plant_name_ferc1                False
# fuel_type_code_pudl             False
# fuel_unit                        True
# fuel_qty_burned                 False
# fuel_mmbtu_per_unit             False
# fuel_cost_per_unit_burned       False
# fuel_cost_per_unit_delivered    False
# fuel_cost_per_mmbtu             False
# dtype: bool

# %%
# then we remove the rows with empty values NOTE: df is your data frame

# %%
dropped_values = df.dropna()

# %%
dropped_values
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
# if we compare our df data frame with the dropped values data frame we will see that the number of rows has been reduced in our 
# dropped value data frame

# %%
#we will drop our columns that have na values

# %%
dropped_values_column= df.dropna(axis= 1)

# %%
dropped_values_column
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl  fuel_qty_burned  \
# 0                  rockport                coal        5377489.0
# 1      rockport total plant                coal       10486945.0
# ...

# %%
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
# comparing dropped_value_column to our original data frame df we can see that a colun has been dropped which is our feul units
# recall that

# %%
df.isna().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#from the above cell we notice that fuel units is the only column with empty values

# %%
#to get our the whole column in the data frame we can use the columns method

# %%
df_column = df.columns[1:]

# %%
df_column
# Out:
# Index(['utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
#using boolean to get a column in your data frame we will print the 6-8th column

# %%
df_column_bool = df.columns[[False,False,False,False,False,True,True,True,False,False,False]]

# %%
df_column_bool
# Out:
# Index(['fuel_unit', 'fuel_qty_burned', 'fuel_mmbtu_per_unit'], dtype='object')

# %%
# we can append two data frames together

# %%
df_1_10 = df[1:11]

# %%
# we created another data frame df_1_10 which contains 10 elements from our data frame df

# %%
df_1_10
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
#
#         plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 1   rockport total plant                coal       ton       10486945.0
# 2                 gorgas                coal       ton        2978683.0
# 3                  barry                coal       ton        3739484.0
# ...

# %%
df_30_40 = df[30:41]

# %%
df_30_40
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 30   f1_fuel_1994_12_7_0_8                 7         1994
# 31  f1_fuel_1994_12_7_0_10                 7         1994
# 32  f1_fuel_1994_12_7_0_11                 7         1994
# 33  f1_fuel_1994_12_7_0_13                 7         1994
# 34   f1_fuel_1994_12_7_1_1                 7         1994
# 35   f1_fuel_1994_12_7_1_2                 7         1994
# 36   f1_fuel_1994_12_7_1_4                 7         1994
# 37   f1_fuel_1994_12_7_1_5                 7         1994
# 38  f1_fuel_1994_12_7_1_10                 7         1994
# 39   f1_fuel_1994_12_7_2_2                 7         1994
# 40   f1_fuel_1994_12_7_2_4                 7         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 30            4 corners                 gas       mcf         230205.0
# 31            4 corners                coal       ton         867805.0
# ...

# %%
df_merge = df_1_10.append(df_30_40)

# %%
df_merge
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
# 30   f1_fuel_1994_12_7_0_8                 7         1994
# 31  f1_fuel_1994_12_7_0_10                 7         1994
# 32  f1_fuel_1994_12_7_0_11                 7         1994
# 33  f1_fuel_1994_12_7_0_13                 7         1994
# 34   f1_fuel_1994_12_7_1_1                 7         1994
# ...

# %%
#in order to drop a particular column we can used the drop method

# %%
df_drop = df.drop(columns = ['report_year','fuel_unit'])

# %%
#drops two columns from our data frame

# %%
df_drop
# Out:
#                      record_id  utility_id_ferc1      plant_name_ferc1  \
# 0        f1_fuel_1994_12_1_0_7                 1              rockport
# 1       f1_fuel_1994_12_1_0_10                 1  rockport total plant
# 2        f1_fuel_1994_12_2_0_1                 2                gorgas
# 3        f1_fuel_1994_12_2_0_7                 2                 barry
# 4       f1_fuel_1994_12_2_0_10                 2             chickasaw
# ...                        ...               ...                   ...
# 29518  f1_fuel_2018_12_12_0_13                12    neil simpson ct #1
# 29519   f1_fuel_2018_12_12_1_1                12  cheyenne prairie 58%
# 29520  f1_fuel_2018_12_12_1_10                12     lange ct facility
# 29521  f1_fuel_2018_12_12_1_13                12       wygen 3 bhp 52%
# 29522  f1_fuel_2018_12_12_1_14                12       wygen 3 bhp 52%
#
#       fuel_type_code_pudl  fuel_qty_burned  fuel_mmbtu_per_unit  \
# ...

# %%
#noww we will drop the last 2 rows

# %%
df_drop_row = df.drop(index=[29519,29520])

# %%
df_drop_row
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29516   f1_fuel_2018_12_12_0_8                12         2018
# 29517  f1_fuel_2018_12_12_0_10                12         2018
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
#the tail function is used to view the last 5 elements in the data frame

# %%
df_drop_row.tail()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 29516   f1_fuel_2018_12_12_0_8                12         2018
# 29517  f1_fuel_2018_12_12_0_10                12         2018
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 29516  neil simpson unit 2                coal       ton         491913.0
# 29517     wyodak - bhp 20%                coal       ton         409637.0
# 29518   neil simpson ct #1                 gas       mcf          18799.0
# 29521      wygen 3 bhp 52%                coal       ton         315945.0
# 29522      wygen 3 bhp 52%                 gas       mcf          17853.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 29516               16.100                      14.76
# ...

# %%
#we can see that the row number 29519 and 29520 has been dropped from the data frame

# %%
new_df = df.rename(columns= {'fuel_qty_burned': 'new_fuel_qty','fuel_unit':'e don cost'})

# %%
new_df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl e don cost  new_fuel_qty  \
# 0                  rockport                coal        ton     5377489.0
# ...

# %%
#this new function allows us to slice both row and columns

# %%
first_last_df  = df.loc[[1,29522]]

# %%
first_last_df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 1      rockport total plant                coal       ton       10486945.0
# 29522       wygen 3 bhp 52%                 gas       mcf          17853.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 1                   16.592                      18.58
# 29522                1.059                       0.00
#
#        fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 1                             18.53                 1.12
# 29522                          0.00                11.68

# %%
#the df.loc[[1,29522]] prints the first and last row of our data frame df
